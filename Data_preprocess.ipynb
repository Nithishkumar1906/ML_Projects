# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\hp\Desktop\Tech Mango\TA_restaurants_curated.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125527 entries, 0 to 125526
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         125527 non-null  int64
#  1   Name               125527 non-null  object
#  2   City               125527 non-null  object
#  3   Cuisine Style      94176 non-null   object
#  4   Ranking            115876 non-null  float64
#  5   Rating             115897 non-null  float64
#  6   Price Range        77672 non-null   object
#  7   Number of Reviews  108183 non-null  float64
#  8   Reviews            115911 non-null  object
#  9   URL_TA             125527 non-null  object
#  10  ID_TA              125527 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 10.5+ MB

# %%
dataset.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
# ...

# %%
dataset['Reviews'][0]
# Out:
# "[['Just like home', 'A Warm Welcome to Wintry Amsterdam'], ['01/03/2018', '01/01/2018']]"

# %%
dataset['Reviews_Lower'] = dataset['Reviews'].str.lower()

# %%
dataset.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
# ...

# %%
dataset['Reviews_Lower'] = dataset['Reviews_Lower'].apply(lambda x: re.sub(r"\s+", " ", str(x)).strip())

# %%
dataset['Reviews_Lower'] = dataset['Reviews_Lower'].apply(lambda x: re.sub(r"[^\w\s]", "", str(x)))

# %%
dataset.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
# ...

# %%
dataset['Tokenize'] = dataset['Reviews_Lower'].apply(word_tokenize)

# %%
dataset['Tokenize'][0]
# Out:
# ['just',
#  'like',
#  'home',
#  'a',
#  'warm',
#  'welcome',
#  'to',
#  'wintry',
#  'amsterdam',
#  '01032018',
#  '01012018']

# %%
ps = PorterStemmer()

# %%
dataset['Stemmer'] = dataset['Tokenize'].apply(lambda X: [ps.stem(token) for token in X])

# %%
lemmatizer = WordNetLemmatizer()

# %%
dataset.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
# ...

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')  # Required resource

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
dataset['Lemmatizer'] = dataset['Tokenize'].apply(lambda X : [lemmatizer.lemmatize(token) for token in X])

# %%
dataset['Lemmatizer'][0]
# Out:
# ['just',
#  'like',
#  'home',
#  'a',
#  'warm',
#  'welcome',
#  'to',
#  'wintry',
#  'amsterdam',
#  '01032018',
#  '01012018']

# %%
token_clean = sum(dataset['Stemmer'],[])

# %%
unigrams = (pd.Series(nltk.ngrams(Tokenize , 1)).plot.bar())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 unigrams = (pd.Series(nltk.ngrams(Tokenize , 1)).plot.bar())
#
# NameError: name 'Tokenize' is not defined
