# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\hp\anaconda3\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\hp\anaconda3\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\hp\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hp\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hp\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\hp\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\hp\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\hp\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\hp\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0)
# Requirement already satisfied: wrapt in c:\users\hp\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)

# %%
import spacy
import pandas as pd

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 4.8 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.3/12.8 MB 4.3 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.4 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 4.1 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.9 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 4.0 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.8 MB 4.2 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 4.1 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 4.1 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.8 MB 4.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 4.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 4.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.8 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "Although Nithish was exhausted after completing 110 sections of his AI course in a single day, he still managed to stay focused and study NLP concepts late into the night with remarkable dedication."
print(text)
# Out:
# Although Nithish was exhausted after completing 110 sections of his AI course in a single day, he still managed to stay focused and study NLP concepts late into the night with remarkable dedication.

# %%
doc = nlp(text)
pos_data = pd.DataFrame(columns=['word','pos_tag'])

# %%
for X in doc:
    pos_data = pd.concat([pos_data, pd.DataFrame.from_records([{'word':X.text,'pos_tag':X.pos_}])])

# %%
pos_data.head(15)
# Out:
#          word pos_tag
# 0    Although   SCONJ
# 0     Nithish   PROPN
# 0         was     AUX
# 0   exhausted     ADJ
# 0       after     ADP
# 0  completing    VERB
# 0         110     NUM
# 0    sections    NOUN
# 0          of     ADP
# 0         his    PRON
# 0          AI   PROPN
# 0      course    NOUN
# 0          in     ADP
# 0           a     DET
# 0      single     ADJ

# %%
pos_data_count = pos_data.groupby(['pos_tag'])['word'].count().sort_values(ascending=True)

# %%
pos_data_count.head(10)
# Out:
# pos_tag
# AUX      1
# CCONJ    1
# NUM      1
# PART     1
# SCONJ    1
# PUNCT    2
# DET      2
# ADV      2
# PRON     2
# PROPN    3
# Name: word, dtype: int64

# %%
nouns_data = pos_data[pos_data['pos_tag'] == 'NOUN']
nouns_data
# Out:
#          word pos_tag
# 0    sections    NOUN
# 0      course    NOUN
# 0         day    NOUN
# 0    concepts    NOUN
# 0       night    NOUN
# 0  dedication    NOUN

# %%
Adj_data = pos_data[pos_data['pos_tag'] == 'ADJ']
Adj_data
# Out:
#          word pos_tag
# 0   exhausted     ADJ
# 0      single     ADJ
# 0     focused     ADJ
# 0  remarkable     ADJ

# %% [markdown]
# Named Entity Recognition(NER)

# %%
from spacy import displacy
from spacy import tokenizer
import re

# %%
text_1 = "On April 27, 2023, Elon Musk announced at a Tesla event in Berlin that SpaceX would partner with NASA to launch a new satellite from Cape Canaveral, while also expanding operations in Bengaluru, India."
print(text_1)
# Out:
# On April 27, 2023, Elon Musk announced at a Tesla event in Berlin that SpaceX would partner with NASA to launch a new satellite from Cape Canaveral, while also expanding operations in Bengaluru, India.

# %%
doc_1 = nlp(text_1)

# %%
for X in doc_1.ents:
    print(X.text,X.label_)
# Out:
# April 27, 2023 DATE
# Elon Musk PERSON
# Tesla NORP
# Berlin GPE
# SpaceX PERSON
# NASA ORG
# Cape Canaveral GPE
# Bengaluru GPE
# India GPE

# %%
displacy.render(doc_1,style = "dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ce828d612e9d44f2b54fb8417aac37b0-0" class="displacy" width="6000" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">On</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">April</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">27,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">2023,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Elon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Musk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">announced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Tesla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">event</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Berlin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">SpaceX</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">partner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">NASA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">launch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">satellite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Cape</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Canaveral,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">while</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">expanding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">operations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curr

# %%
displacy.render(doc_1,style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 27, 2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced at a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  event in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SpaceX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  would partner with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NASA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to launch a new satellite from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cape Canaveral
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , while also expanding operations in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bengaluru
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %%
text_1_clean = re.sub(r"[^\w\s]",'',text_1).lower()
print(text_1_clean)
# Out:
# on april 27 2023 elon musk announced at a tesla event in berlin that spacex would partner with nasa to launch a new satellite from cape canaveral while also expanding operations in bengaluru india

# %%
text_1_lower = nlp(text_1_clean)

# %%
displacy.render(text_1_lower,style="ent",jupyter= True)

# %%
bbc_news = pd.read_csv(r"C:\Users\hp\Desktop\Tech Mango\bbc_news.csv")

# %%
bbc_news.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# 1  https://www.bbc.co.uk/news/world-europe-606418...
# 2  https://www.bbc.co.uk/news/business-60623941?a...
# 3  https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4  https://www.bbc.co.uk/news/business-60642786?a...
#
#                                          description
# 0  The Ukrainian president says the country will ...
# 1  Jeremy Bowen was on the frontline in Irpin, as...
# 2  One of the world's biggest fertiliser firms sa...
# 3  The parents of the Manchester Arena bombing's ...
# 4  Consumers are feeling the impact of higher ene...

# %%
bbc_title = pd.DataFrame(bbc_news['title'])

# %%
bbc_title.head()
# Out:
#                                                title
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import re

# %%
bbc_title['lowercase'] = bbc_title['title'].str.lower()

# %%
bbc_title.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                                            lowercase
# 0  ukraine: angry zelensky vows to punish russian...
# 1  war in ukraine: taking cover in a town under a...
# 2         ukraine war 'catastrophic for global food'
# 3  manchester arena bombing: saffie roussos's par...
# 4  ukraine conflict: oil price soars to highest l...

# %%
bbc_title['no_puc_words'] = bbc_title['lowercase'].apply(lambda x: re.sub(r"[^\w\s]", "", str(x)))

# %%
bbc_title.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                                            lowercase  \
# 0  ukraine: angry zelensky vows to punish russian...
# 1  war in ukraine: taking cover in a town under a...
# 2         ukraine war 'catastrophic for global food'
# 3  manchester arena bombing: saffie roussos's par...
# 4  ukraine conflict: oil price soars to highest l...
#
#                                         no_puc_words
# 0  ukraine angry zelensky vows to punish russian ...
# 1  war in ukraine taking cover in a town under at...
# 2           ukraine war catastrophic for global food
# 3  manchester arena bombing saffie roussoss paren...
# 4  ukraine conflict oil price soars to highest le...

# %%
bbc_title['tokenize'] = bbc_title['no_puc_words'].apply(lambda X : word_tokenize(X))

# %%
bbc_title.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                                            lowercase  \
# 0  ukraine: angry zelensky vows to punish russian...
# 1  war in ukraine: taking cover in a town under a...
# 2         ukraine war 'catastrophic for global food'
# 3  manchester arena bombing: saffie roussos's par...
# 4  ukraine conflict: oil price soars to highest l...
#
#                                         no_puc_words  \
# 0  ukraine angry zelensky vows to punish russian ...
# 1  war in ukraine taking cover in a town under at...
# 2           ukraine war catastrophic for global food
# 3  manchester arena bombing saffie roussoss paren...
# 4  ukraine conflict oil price soars to highest le...
#
#                                             tokenize
# 0  [ukraine, angry, zelensky, vows, to, punish, r...
# 1  [war, in, ukraine, taking, cover, in, a, town,...
# 2    [ukraine, war, catastrophic, for, global, food]
# 3  [manchester, arena, bombing, saffie, roussoss,...
# 4  [ukraine, conflict, oil, price, soars, to, hig...

# %% [markdown]
# WORKING POS & NER WITH BBC DATASETS

# %%
token_raw = sum(bbc_title['tokenize'],[])

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
# Ensure token_raw contains only valid strings
token_raw = []

for tokens in bbc_title['tokenize']:
    if isinstance(tokens, list):
        for token in tokens:
            if isinstance(token, str) and token.strip() != "":
                token_raw.append(token)

# %%
# Join and truncate first 100,000 characters (safe for spaCy)
text_data = ' '.join(token_raw)[:100000]
spacy_doc = nlp(text_data)

# %%
pos_def = pd.DataFrame(columns = ['token','pos_tags'])

# %%
for X in spacy_doc:
    pos_def = pd.concat([pos_def, pd.DataFrame.from_records([{'token':X.text,'pos_tag':X.pos_}])])

# %%
pos_def_count = pos_def.groupby(['token','pos_tag']).size().reset_index(name = 'counts')
pos_def_count.head(10)
# Out:
#          token pos_tag  counts
# 0           01     NUM       1
# 1           02     NUM       2
# 2            1     NUM       4
# 3           10     NUM      11
# 4          100     NUM       3
# 5       100000     NUM       1
# 6  1000yearold    NOUN       1
# 7         100k     NUM       1
# 8   100yearold   PROPN       1
# 9         10bn     ADJ       1

# %%
Nouns = pos_def_count[pos_def_count.pos_tag=="NOUN"]
Nouns
# Out:
#             token pos_tag  counts
# 6     1000yearold    NOUN       1
# 10          10man    NOUN       1
# 19          12day    NOUN       1
# 26         15inch    NOUN       1
# 33           18th    NOUN       1
# ...           ...     ...     ...
# 5343   youngsters    NOUN       1
# 5347      youtube    NOUN       1
# 5349            z    NOUN       1
# 5359     zelensky    NOUN       1
# 5370         zone    NOUN       1
#
# [2235 rows x 3 columns]

# %%
Verbs = pos_def_count[pos_def_count.pos_tag=="VERB"]
Verbs
# Out:
#            token pos_tag  counts
# 119    abandoned    VERB       3
# 122       abduct    VERB       1
# 123     abducted    VERB       1
# 133   abramovich    VERB       2
# 139    academies    VERB       1
# ...          ...     ...     ...
# 5310     wounded    VERB       2
# 5312        wows    VERB       1
# 5315       write    VERB       2
# 5316       wrote    VERB       1
# 5369   zombified    VERB       1
#
# [1112 rows x 3 columns]

# %%
Ner_df = pd.DataFrame(columns=['token','NER_tag'])

# %%
for X in spacy_doc.ents:
    print(X.text,X.label_)
# Out:
# ukraine GPE
# zelensky PERSON
# russian NORP
# 2008 DATE
# 50 CARDINAL
# netflix GPE
# russia GPE
# fourth ORDINAL
# russia GPE
# thousands CARDINAL
# 11 CARDINAL
# russian NORP
# ukraine GPE
# ukraine GPE
# putin PERSON
# prorussian trolls ukraine maps new ORG
# south five DATE
# ukraine russian NORP
# european NORP
# ukraine russians NORP
# boycotts NORP
# kherson PERSON
# russian NORP
# belfast GPE
# russian NORP
# russia GPE
# ukraine GPE
# russia GPE
# bbc ukrainian ORG
# ukraine russian NORP
# nato ORG
# indian NORP
# first ORDINAL
# the week DATE
# joe perry PERSON
# gb ski pairings PERSON
# two CARDINAL
# uk GPE
# five CARDINAL
# fourth ORDINAL
# england GPE
# uk GPE
# england GPE
# 2008 DATE
# one CARDINAL
# scottish NORP
# capsizes ORG
# norway ukraine irish medical FAC
# one CARDINAL
# scottish NORP
# capsizes ORG
# norway ukraine FAC
# one CARDINAL
# scottish NORP
# australian NORP
# new zealand GPE
# one CARDINAL
# scottish NORP
# australian NORP
# russian NORP
# ivan kuliak PERSON
# thousands CARDINAL
# ukraine GPE
# ukraine irish medical ORG
# sumy ukraine india doctor ORG
# all hours TIME
# 82 CARDINAL
# sheeran GPE
# canadian NORP
# dutch NORP
# one CARDINAL
# thousands CARDINAL
# ukraine ukraine maps ukraine FAC
# russian NORP
# ukraine GPE
# five CARDINAL
# ukraine irish NORP
# england henderson PERSON
# six CARDINAL
# six CARDINAL
# 2022 DATE
# 70 DATE
# russian NORP
# thai NORP
# irpin ukraine volodymyr zelensky ORG
# all hours TIME
# 82 CARDINAL
# boris johnson PERSON
# ed sheeran PERSON
# russia ukraine war pm FAC
# russian NORP
# iowa GPE
# seven CARDINAL
# two CARDINAL
# day 12 DATE
# russian NORP
# ukraine GPE
# 12day CARDINAL
# russian NORP
# ukraine GPE
# ukraine GPE
# irish NORP
# red bulls horner man ORG
# england GPE
# uk GPE
# russia GPE
# ukraine volodymyr zelensky NORP
# 300 CARDINAL
# nearly 50 years DATE
# billions CARDINAL
# five CARDINAL
# russians NORP
# 723 CARDINAL
# russia GPE
# wang PERSON
# pixar PERSON
# irish NORP
# south koreas GPE
# uk GPE
# ukraine GPE
# angel city GPE
# eni ORG
# los angeles GPE
# russia GPE
# uk GPE
# khans rematch PERSON
# australia GPE
# pakistan GPE
# world cup war EVENT
# ukraine west GPE
# russia GPE
# ukraine mcdonalds cocacola FAC
# russian NORP
# ukraine GPE
# uk GPE
# ukraine NORP
# zelensky PERSON
# winston churchill PERSON
# russian NORP
# uk ukrainian ORG
# pasha lee PERSON
# russian NORP
# almost two million CARDINAL
# ukraine ukraine war FAC
# russia GPE
# poland GPE
# russian NORP
# zelensky PERSON
# usuk oil ORG
# zelenskys PERSON
# secrets drone boss henri ORG
# irish NORP
# ukraine GPE
# ukraine GPE
# zelensky PERSON
# uk GPE
# uk GPE
# inter ORG
# klopp bairstow ton PERSON
# england GPE
# west indies ORG
# seven andy murray QUANTITY
# ukraine GPE
# 2022 CARDINAL
# march DATE
# cup deandra dottin PERSON
# russia GPE
# ukraine white house ORG
# uk GPE
# liz truss ukraine private PERSON
# 14bn ORDINAL
# russian NORP
# dozens CARDINAL
# mans NORP
# madrid GPE
# 31 CARDINAL
# paris GPE
# 32 CARDINAL
# agg karim benzema hattrick inspires superb ORG
# russians NORP
# soviet NORP
# russia GPE
# 14 CARDINAL
# james patterson PERSON
# first ORDINAL
# halifax acapulco club ORG
# ukrainerussia war ORG
# years DATE
# kevin PERSON
# second ORDINAL
# russians NORP
# eu PERSON
# last eight DATE
# harvey elliott PERSON
# russian NORP
# russia GPE
# russian NORP
# putin PERSON
# 150 days DATE
# n korea GPE
# uk GPE
# three CARDINAL
# england GPE
# 20 CARDINAL
# putin PERSON
# ukraine GPE
# uk GPE
# russia GPE
# day 15 DATE
# russian NORP
# ukraine GPE
# russian NORP
# the week DATE
# indian NORP
# uk GPE
# teddy PERSON
# a day DATE
# 28k DATE
# russian NORP
# malis NORP
# russia GPE
# century DATE
# 1 CARDINAL
# thomas tuchel PERSON
# west ham GPE
# russian NORP
# thousands CARDINAL
# texas GPE
# france GPE
# six CARDINAL
# west indies GPE
# zak crawley hits PERSON
# hundred CARDINAL
# four CARDINAL
# 386 russian mps QUANTITY
# russian NORP
# ukraine GPE
# polish NORP
# india GPE
# australian NORP
# ukraine GPE
# england head coach PERSON
# second ORDINAL
# argentina GPE
# paris GPE
# first ORDINAL
# london GPE
# ukraine GPE
# russian NORP
# iran GPE
# five CARDINAL
# this year DATE
# william PERSON
# two CARDINAL
# england GPE
# london GPE
# northampton GPE
# six CARDINAL
# belgium ukraine FAC
# russia GPE
# russian NORP
# russia GPE
# kenya GPE
# 19bn ORDINAL
# uk GPE
# uk airport FAC
# six CARDINAL
# france GPE
# triumph omicron vs zerocovid PERSON
# china GPE
# 2022 CARDINAL
# five CARDINAL
# second ORDINAL
# liverpool GPE
# two CARDINAL
# three CARDINAL
# danny murphy PERSON
# 01 CARDINAL
# liverpool GPE
# klopps ORG
# madrid GPE
# clasico GPE
# first ORDINAL
# indian NORP
# england GPE
# russian NORP
# a week ago DATE
# 17monthold CARDINAL
# two CARDINAL
# swedish NORP
# yvan colonna PERSON
# corsican NORP
# jihadist NORP
# china GPE
# uk GPE
# ben wallace PERSON
# six years ago DATE
# less than 2 CARDINAL
# london GPE
# four CARDINAL
# russia GPE
# russian NORP
# daily DATE
# bbc ORG
# 2022 CARDINAL
# 60 seconds TIME
# south asian NORP
# russian NORP
# gold david beckham PERSON
# uk GPE
# brazil GPE
# ghana GPE
# anderson PERSON
# england GPE
# first ORDINAL
# 28 years DATE
# sutton ORG
# england badminton championships FAC
# lee zii jia records PERSON
# 372 CARDINAL
# kmh backhand mitchell ORG
# 100k PRODUCT
# florida GPE
# evan neumann us PERSON
# william PERSON
# jamaica GPE
# new zealand GPE
# almost 400 migrants QUANTITY
# uk GPE
# anne frank PERSON
# china GPE
# william collins PERSON
# ukraine GPE
# hundreds CARDINAL
# one CARDINAL
# superyachts CARDINAL
# russian NORP
# 3 CARDINAL
# russian NORP
# russia GPE
# ukraine GPE
# harry styles PERSON
# texas GPE
# american NORP
# uk GPE
# 2022 18 DATE
# this years DATE
# one CARDINAL
# russians NORP
# thai NORP
# ukraine GPE
# billions CARDINAL
# liverpool GPE
# up to six weeks DATE
# spring DATE
# spring DATE
# rishi sunak PERSON
# ukraine GPE
# william PERSON
# jamaica GPE
# russian NORP
# oksana baulina PERSON
# china GPE
# jeffrey epsteins PERSON
# 37 CARDINAL
# madeleine albright PERSON
# first ORDINAL
# us GPE
# boris becker PERSON
# julian assange ORG
# national trust ukraine ORG
# bbc world ORG
# spring DATE
# spring DATE
# bbc ORG
# 2022 DATE
# 1956 DATE
# spring DATE
# one CARDINAL
# david solomon PERSON
# taliban ORG
# afghan NORP
# four CARDINAL
# william collins PERSON
# madeleine albright PERSON
# 2022 DATE
# uk GPE
# pakistan GPE
# 100 CARDINAL
# kane PERSON
# qatar GPE
# zelensky PERSON
# ukrainian NORP
# poland GPE
# russia GPE
# ukraine GPE
# kremlin ORG
# a million CARDINAL
# a week pm DATE
# peter hebblethwaite PERSON
# 300 CARDINAL
# david PERSON
# ali harbi ali PERSON
# eu PERSON
# russia GPE
# nato ORG
# russia GPE
# three CARDINAL
# uk GPE
# belfast GPE
# russia GPE
# assert control ukraine PERSON
# russians NORP
# ukraine GPE
# ukraine GPE
# 76yearold CARDINAL
# putin ukraine daily PERSON
# zelensky PERSON
# russia GPE
# ukraine GPE
# scotland GPE
# second ORDINAL
# michael PERSON
# the week DATE
# po australia ORG
# netflix boss scott stuber ORG
# russia GPE
# 25 years DATE
# notts county GPE
# nato ORG
# spanish NORP
# 100 CARDINAL
# liverpool GPE
# italy GPE
# six CARDINAL
# 2021 DATE
# five CARDINAL
# taylor PERSON
# 50 CARDINAL
# khan PERSON
# uk GPE
# ukraine GPE
# metro FAC
# 21 CARDINAL
# switzerland GPE
# shaw ORG
# harry kane PERSON
# three CARDINAL
# china GPE
# 132 CARDINAL
# michael PERSON
# sergio NORP
# saudi arabia GPE
# moscow GPE
# russian NORP
# ukraine ukraine FAC
# maps ukraine defence ORG
# russian NORP
# ukraine GPE
# taylor PERSON
# 1000yearold CARDINAL
# bbc ORG
# belfast GPE
# japanese NORP
# the cage week DATE
# 19 CARDINAL
# march 2022 DATE
# john lennons PERSON
# liverpool GPE
# japan GPE
# 2022 DATE
# uk GPE
# tory NORP
# scotland GPE
# six CARDINAL
# ireland GPE
# belgium GPE
# six CARDINAL
# 126 CARDINAL
# new zealand GPE
# six CARDINAL
# ireland GPE
# ukraine GPE
# russia GPE
# shanghai GPE
# china GPE
# 2022 CARDINAL
# el salvador GPE
# 62 CARDINAL
# a day DATE
# motheroftwo CARDINAL
# afghanistan GPE
# taliban ORG
# bbc tv ORG
# covid allclear snowdonia PERSON
# putin PERSON
# russia GPE
# thousands CARDINAL
# russian NORP
# russia GPE
# ukraine GPE
# putin PERSON
# belfast GPE
# max PERSON
# carol vorderman PERSON
# five CARDINAL
# india GPE
# indian NORP
# korean NORP
# palestinian NORP
# 10wicket CARDINAL
# third ORDINAL
# 10 CARDINAL
# 90 CARDINAL
# barrow highlights ORG
# josh warrington PERSON
# kiko martinez PERSON
# six CARDINAL
# france GPE
# italy GPE
# first ORDINAL
# boris becker PERSON
# 21 years DATE
# 12 CARDINAL
# 13 CARDINAL
# london GPE
# 1 CARDINAL
# boris nemtsov PERSON
# putin PERSON
# ukraine GPE
# russians NORP
# putin PERSON
# ukraine ukraine FAC
# russia GPE
# thousands CARDINAL
# russian NORP
# russian NORP
# boris nemtsov PERSON
# john sentamu PERSON
# philip PERSON
# disney tv ORG
# first ORDINAL
# uk GPE
# china GPE
# alzheimers neil PERSON
# north korea GPE
# ten CARDINAL
# van gaal PERSON
# third ORDINAL
# one CARDINAL
# two months DATE
# canada GPE
# cup john herdman PERSON
# english NORP
# chris rock GPE
# 2022 DATE
# two CARDINAL
# uk GPE
# 2022 DATE
# 2022 DATE
# 2022 DATE
# 2022 DATE
# 2022 DATE
# five CARDINAL
# westminster abbey shrewsbury FAC
# 201 CARDINAL
# twenty CARDINAL
# jada pinkett PERSON
# jackie weaver PERSON
# england GPE
# this week DATE
# five CARDINAL
# israel GPE
# dozens CARDINAL
# russian NORP
# four eu QUANTITY
# six month DATE
# 20 and 50 CARDINAL
# max mosley PERSON
# boris becker PERSON
# wimbledon trophies PERSON
# russia GPE
# russian NORP
# russia GPE
# the red cross ORG
# daily DATE
# prince philip thanksgiving PERSON
# joão carvalhaes PERSON
# 1958 DATE
# india GPE
# russian NORP
# french NORP
# moissac ORG
# 30 CARDINAL
# ivory coast LOC
# qatar GPE
# salah ORG
# portugal GPE
# 20 CARDINAL
# north macedonia LOC
# first ORDINAL
# 2022 DATE
# javid ukraine PERSON
# putin PERSON
# germany GPE
# austria GPE
# 33 CARDINAL
# boris johnson PERSON
# bruce willis PERSON
# aphasia jamie PERSON
# two CARDINAL
# russia GPE
# scottish NORP
# syrians NORP
# russia GPE
# russian NORP
# russian NORP
# 12 CARDINAL
# australia GPE
# australian NORP
# east coast LOC
# elton john PERSON
# ed sheeran PERSON
# 600 CARDINAL
# mouth tipu sultan painting ORG
# british NORP
# india GPE
# one CARDINAL
# 10 CARDINAL
# finland GPE
# european union ORG
# african NORP
# paris GPE
# 22 CARDINAL
# 43 CARDINAL
# agg ramona bachmann scores ORG
# beth mooney PERSON
# nigel huddleston PERSON
# south africa GPE
# paris GPE
# nasser alkhelaifi PERSON
# european NORP
# league ffp barcelona PERSON
# 52 CARDINAL
# madrid GPE
# 83 CARDINAL
# russian NORP
# ukraine GPE
# russian NORP
# rishi PERSON
# islamic NORP
# uk GPE
# spring DATE
# lincoln ORG
# french NORP
# russian NORP
# russia GPE
# zelensky ukraine PERSON
# russia GPE
# mariupol ORG
# ukraine ukraine ORG
# india GPE
# same day DATE
# russia GPE
# ukraine GPE
# putin PERSON
# kevin lee PERSON
# ukraine GPE
# zelensky PERSON
# australian NORP
# african NORP
# 5800mile CARDINAL
# uk GPE
# russia GPE
# pakistans NORP
# khan PERSON
# 20 CARDINAL
# 31 CARDINAL
# london GPE
# qatar GPE
# 129 CARDINAL
# six CARDINAL
# five CARDINAL
# 202223 DATE
# 2022 CARDINAL
# hassan PERSON
# 1918 DATE
# harry smith PERSON
# october DATE
# 49 million CARDINAL
# uk GPE
# russia GPE
# maxwell ORG
# hong kong GPE
# qatar GPE
# england GPE
# prince andrew repays PERSON
# first ORDINAL
# russian NORP
# russia GPE
# russia GPE
# the week DATE
# 2022 DATE
# qatar GPE
# qatar 2022 ORG
# wolverhampton GPE
# china GPE
# sunday DATE
# west ham LOC
# england GPE
# more than 150 CARDINAL
# david moyes PERSON
# united rugby championship sharks ORG
# 513 CARDINAL
# liverpool GPE
# klopp PERSON
# fifa ORG
# qatar GPE
# 2022 CARDINAL
# 10 CARDINAL
# 2018 DATE
# five CARDINAL
# martin ORG
# second ORDINAL
# manchester airport FAC
# tory NORP
# david warburton PERSON
# ukraine johnson PERSON
# zelensky PERSON
# 83 CARDINAL
# english NORP
# three CARDINAL
# palestinian NORP
# israeli NORP
# west bank GPE
# world cup england EVENT
# australia GPE
# russian NORP
# ukraine ukraine GPE
# russia GPE
# hungary GPE
# mike dean PERSON
# 22 years DATE
# one CARDINAL
# charlies ORG
# 26 CARDINAL
# two years DATE
# 2017 DATE
# uk GPE
# liverpool GPE
# christian NORP
# second ORDINAL
# thousands CARDINAL
# kinghorn beach GPE
# 7 CARDINAL
# uk GPE
# national fairytale somalia drought ORG
# 350000 CARDINAL
# france GPE
# australia GPE
# 22 CARDINAL
# liverpool GPE
# alan shearer PERSON
# manchester city GPE
# 22 CARDINAL
# liverpool GPE
# two CARDINAL
# australian NORP
# charles leclerc PERSON
# manchester city DATE
# 22 CARDINAL
# liverpool GPE
# six CARDINAL
# italy GPE
# first ORDINAL
# 18th DATE
# british NORP
# ukraine GPE
# kramatorsk train PERSON
# russian NORP
# one CARDINAL
# ahmad khan PERSON
# two CARDINAL
# texas GPE
# new york GPE
# 25 CARDINAL
# russian NORP
# marina LOC
# ovsyannikova ORG
# german NORP
# russian NORP
# ukraine GPE
# austria GPE
# putin PERSON
# russia GPE
# nato ORG
# zelensky PERSON
# russia GPE
# ukraine GPE
# russia GPE
# east ukraine LOC
# india GPE
# 2022 DATE
# sony ORG
# white house ORG
# 2022 CARDINAL
# 7 CARDINAL
# yemen GPE
# afghanistan GPE
# shanghai GPE
# 10bn ORDINAL
# indian NORP
# 4 CARDINAL
# david amess PERSON
# bihar GPE
# ahmad khan PERSON
# northern ireland v GPE
# park callaghan mlb PERSON
# miami GPE
# colombia GPE
# madrid GPE
# 5000 CARDINAL
# 17 DATE
# third ORDINAL
# luton boris johnson PERSON
# rishi sunak ORG
# 1992 DATE
# brooklyn GPE
# new york GPE
# uk GPE
# 74 CARDINAL
# britain GPE
# shanghai GPE
# china GPE
# johnny PERSON
# north korea GPE
# madrid GPE
# 23 CARDINAL
# 54 CARDINAL
# champions league exit ORG
# russia GPE
# eastern ORG
# 27yearold CARDINAL
# chyrkova NORP
# 12000 CARDINAL
# winter DATE
# oxford street ORG
# 2022 CARDINAL
# trafalgar square PERSON
# boris johnson PERSON
# rishi sunak ORG
# ukraine GPE
# thomas tuchel chelsea boss PERSON
# northern ireland v england GPE

# %%
displacy.render(spacy_doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  angry
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zelensky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  vows to punish
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  atrocities war in ukraine taking cover in a town under attack ukraine war catastrophic for global food manchester arena bombing saffie roussoss parents on hearing the truth ukraine conflict oil price soars to highest level since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ukraine war pm to hold talks with world leaders on further sanctions ukraine war uk grants
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ukrainian refugee visas so far tiktok limits services as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     netflix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  pulls out of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  covid
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  jab for scotlands vulnerable and testing wind down fears in wales protests across
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  see
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  detained ukraine conflict your guide to understanding day
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  gymnast investigated for wearing prowar symbol on podium next to ukrainian ukraine with placards and tears poles are greeting refugees like family twitter is part of our war effort
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  minister
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  invasion volunteers working on autopilot ukraine crisis the west fights back against
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the disruptor mariupol fires no water and bodies in the street the young ukrainians battling
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prorussian trolls ukraine maps new
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  agreed ceasefire breaks down in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     south five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ways the ukraine war could push up prices ukraine we try to tell them the truth parenting in wartime war in
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ukraine russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  helicopter shot down by missile
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     european
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  peace seems as fragile as ever war in
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ukraine russians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  on
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     boycotts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  sanctions and cancellations ukraine war my citys being shelled but mum wont believe me nuclear plant how close was nuclear plant attack to catastrophe ukraine war why
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kherson
#     <span style="font-size: 0.8em; font-weight
